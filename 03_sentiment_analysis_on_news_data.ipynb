# %% [markdown]
# # 03 - Sentiment Analysis on News Data

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ### nltk downloads

# %%
nltk.download('punkt')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to /home/arabind/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/arabind/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# ### Import the previous data

# %%
news_data = pd.read_pickle('pickle/clean_news_data.pkl')
len(news_data)
# Out:
# 50

# %% [markdown]
# ### Function to Analyse Sentiment

# %%
def analyse_sentiment(text):
    analyse = SentimentIntensityAnalyzer()
    sentiment = analyse.polarity_scores(text)
    return sentiment

# %%
title_negative = list()
title_neutral = list()
title_positive = list()
title_compound = list()
for i in range(50):
    data = analyse_sentiment(news_data['title'][i])
    title_negative.append(data['neg'])
    title_neutral.append(data['neu'])
    title_positive.append(data['pos'])
    title_compound.append(data['compound'])
len(title_negative), len(title_neutral), len(title_positive), len(title_compound)
# Out:
# (50, 50, 50, 50)

# %%
content_negative = list()
content_neutral = list()
content_positive = list()
content_compound = list()
for i in range(50):
    data = analyse_sentiment(news_data['content'][i])
    content_negative.append(data['neg'])
    content_neutral.append(data['neu'])
    content_positive.append(data['pos'])
    content_compound.append(data['compound'])
len(content_negative), len(content_neutral), len(content_positive), len(content_compound)
content_compound
# Out:
# [0.3456,
#  -1.0,
#  0.9949,
#  -0.8998,
#  0.986,
#  -0.9375,
#  -0.8078,
#  -0.9997,
#  0.9996,
#  -0.9937,
#  0.9882,
#  0.9996,
#  0.9985,
#  0.9987,
#  0.9995,
#  0.9923,
#  -0.9998,
#  -0.9983,
#  -0.9954,
#  0.2382,
#  -0.9723,
#  -0.9322,
#  -0.996,
#  0.9998,
#  0.9807,
#  0.9982,
#  -0.803,
#  -0.9999,
#  -0.998,
#  -0.9979,
#  0.9993,
#  -0.5565,
#  0.9921,
#  0.0462,
#  -0.9989,
#  0.9593,
#  0.9989,
#  0.9943,
#  0.9973,
#  0.9743,
#  -0.9936,
#  0.9953,
#  0.9992,
#  0.9958,
#  0.9136,
#  -0.9855,
#  0.8216,
#  0.9968,
#  0.9656,
#  0.9933]

# %%
plt.rcParams['figure.figsize'] = , 10
plt.plot(title_compound)
plt.plot(content_compound)
plt.ylabel('Sentiment')
plt.xlabel('Data')
plt.show()

# %%
paragraph = "It was one of the worst movies I've seen, despite good reviews. Unbelievably bad acting!! Poor direction. VERY poor production. The movie was bad. Very bad movie. VERY bad movie. VERY BAD movie. VERY BAD movie!"

# %%
a = analyse_sentiment(paragraph)
a
# Out:
# {'neg': 0.609, 'neu': 0.391, 'pos': 0.0, 'compound': -0.9921}

# %%
del(a['neg'])
a
# Out:
# {'neu': 0.391, 'pos': 0.0, 'compound': -0.9921}

# %%
line = tokenize.sent_tokenize(paragraph)
line

# %%
sen = SentimentIntensityAnalyzer()
s = sen.polarity_scores(paragraph)
s

# %%
x = tuple(s.keys())
x

# %%
h = tuple(s.values())
h

# %%
plt.bar(x, height=h, width=0.5)
