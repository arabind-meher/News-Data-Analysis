# %% [markdown]
# # 03 - Sentiment Analysis on News Data

# %%
import numpy as np
import pandas as pd
import pickle

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
import matplotlib.pyplot as plt
# %matplotlib

# %% [markdown]
# ### nltk downloads
# <ul>
#     <li>'punkt</li>
#     <li>'vader_lexicon'</li>
# </ul>

# %% [markdown]
# ### Import the previous data

# %%
news_data = pd.read_pickle('pickle/clean_news_data.pkl')
len(news_data)
# Out:
# 50

# %% [markdown]
# ### Function to Analyse Sentiment

# %%
def analyse_sentiment(text):
    analyse = SentimentIntensityAnalyzer()
    sentiment = analyse.polarity_scores(text)
    return sentiment

# %%
title_negative = list()
title_neutral = list()
title_positive = list()
title_compound = list()
for i in range(50):
    data = analyse_sentiment(news_data['title'][i])
    title_negative.append(data['neg'] * 100)
    title_neutral.append(data['neu'] * 100)
    title_positive.append(data['pos'] * 100)
    title_compound.append(data['compound'])
len(title_negative), len(title_neutral), len(title_positive), len(title_compound)
# Out:
# (50, 50, 50, 50)

# %%
content_negative = list()
content_neutral = list()
content_positive = list()
content_compound = list()
for i in range(50):
    data = analyse_sentiment(news_data['content'][i])
    content_negative.append(data['neg'] * 100)
    content_neutral.append(data['neu'] * 100)
    content_positive.append(data['pos'] * 100)
    content_compound.append(data['compound'])
len(content_negative), len(content_neutral), len(content_positive), len(content_compound)
# Out:
# (50, 50, 50, 50)

# %%
plt.rcParams['figure.figsize'] = 20, 5
x = np.arange(50)
width = 0.35
fig, ax = plt.subplots()

rect1 = ax.bar(x - width/2, title_compound, width, label='Title')
recr2 = ax.bar(x + width/2, content_compound, width, label='Content')

ax.set_ylabel('Sentiment')
ax.set_xticks(x)
ax.set_xticklabels(x)
ax.legend()

plt.show()

# %%
plt.rcParams['figure.figsize'] = 20, 5
plt.plot(title_compound, 'blue')
plt.plot(content_compound, 'orange')
plt.ylabel('Sentiment')
plt.xlabel('Data')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 20, 5
x = np.arange(50)
width = 0.35
fig, ax = plt.subplots()

rect1 = ax.bar(x - width/2, title_negative, width, label='Negative', color='red')
recr2 = ax.bar(x + width/2, title_positive, width, label='Positive', color='green')

ax.set_ylabel('Sentiment')
ax.set_xticks(x)
ax.set_xticklabels(x)
ax.legend()

plt.show()

# %%
plt.rcParams['figure.figsize'] = 20, 5
plt.plot(title_negative, 'r')
plt.plot(title_positive, 'g')
plt.xlabel('Title')
plt.ylabel('Percent')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 20, 5
x = np.arange(50)
width = 0.35
fig, ax = plt.subplots()

rect1 = ax.bar(x - width/2, content_negative, width, label='Negative', color='red')
recr2 = ax.bar(x + width/2, content_positive, width, label='Positive', color='green')

ax.set_ylabel('Sentiment')
ax.set_xticks(x)
ax.set_xticklabels(x)
ax.legend()

plt.show()

# %%
plt.rcParams['figure.figsize'] = 20, 5
plt.plot(content_negative, 'r', label='Negative')
plt.plot(content_positive, 'g', label='Positive')
plt.xlabel('Content')
plt.ylabel('Percent')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 20, 5
plt.plot(title_negative, 'p')
plt.plot(content_negative, 'b')
plt.show()

# %%
plt.rcParams['figure.figsize'] = 20, 5
plt.plot(title_positive, 'p')
plt.plot(content_positive, 'b')
plt.show()
